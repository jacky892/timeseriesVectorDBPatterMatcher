# %% [markdown]
# ## Data pack generation
#
# To generate the datapack that can be used to populate the pinecone vector database, run the followings
#
# python katslib/opkatsDataUtil.py
#
# run this notebook (kats_pattern_vectordb.ipynb) to see the pattern matching outcome

# %%
from katslib.opkatsDataUtil import init_kat_index
ki=init_kat_index()
ki.describe_index_stats()

# %%
from opkatsPatternMatcherUtil import opkatsPatternMatcherUtil
opkatsPatternMatcherUtil.match_period_with_vectordb('C')
# Out:
# /home/jackylee/git_tutorial/timeseriesVectorDBPatterMatcher/opkatsPatternMatcherUtil.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['_date']=new_df.index
# /home/jackylee/git_tutorial/timeseriesVectorDBPatterMatcher/katslib/opkatsDataUtil.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['_date']=df.index
# /home/jackylee/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/stattools.py:1906: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   warnings.warn(
# ('qa_C_20221213_20230316', [127.0, 0.9908457930601792, 0.004903056628981301, 0.1890621814563994, 8.683879674024948e-07, 0.00413375498438211, 1.0, 0.47571740965027615, 0.0090309355797801, 5.0, 0.5905511811023622, 1.144016828248867, 112.40502323952303, 1.0427502323711386, 0.5393543229190447, 0.9902721491310582, 0.4858055101713208, 3.7408681835778634e-13, 3.0, 4.0, 104.0, 0.0067766807834777065, 0.9758158065235822, 4.359076737163364, -0.12195693793738617, 0.06143730673651452, -0.5078245069642555, 0.29684859184730295, 1.0423147947602143, 0.0719776774863375, 0.6720721226365304, 0.8225276721169474, -0.28430609867800866, 67.0, 36.0, 0.7376976034913248, 0.08768708493829144, 0.9285096619543892, 0.0, 0.0437513122058264])
# id: <built-in function id>
# id: <built-in function id>
# query_results len is  100
#                            id     score  \
# 0    dr_BPT_20211108_20220208  0.999884
# 1   dr_INVE_20191212_20200316  0.999835
# 2   dr_ARCT_20200311_20200610  0.999822
# 3    dr_HGV_20190510_20190809  0.999784
# 4   dr_HTGM_20200226_20200527  0.999776
# ..                        ...       ...
# 95  dr_CVGI_20220811_20221109  0.999237
# 96  dr_ALDX_20191212_20200316  0.999235
# 97  dr_ENIC_20190524_20190823  0.999228
# 98   dr_IHT_20211025_20220125  0.999224
# 99   dr_CYH_20191212_20200316  0.999219
#
#                                                values
# 0   [125.0, 1.32605743, 0.186817408, 0.319333822, ...
# 1   [127.0, 1.03941202, 0.031611003, 0.318730474, ...
# 2   [128.0, 2.27541828, 0.962953, 0.176573575, 0.0...
# 3   [128.0, 0.947717, 0.008814767, 0.174326971, 6....
# 4   [127.0, 0.362135023, 0.00905408897, 0.34851035...
# ..                                                ...
# 95  [127.0, 0.724467218, 0.0155380275, 0.12210428,...
# 96  [124.0, 0.789832056, 0.0237599779, 0.329740852...
# 97  [125.0, 0.962729096, 0.0018513815, 0.268821537...
# 98  [127.0, 0.781425774, 0.0298394524, 0.175210744...
# 99  [124.0, 1.19984889, 0.112298131, 0.228372946, ...
#
# [93 rows x 3 columns]
# ticker: BPT
# ticker: INVE
# ticker: ARCT
# ticker: HGV
# ticker: HTGM
# ticker: FULC
# ticker: JO
# ticker: AXSM
# ticker: AHCO
# ticker: EIG
