# %% [markdown]
# ## Data pack generation
#
# To generate the datapack that can be used to populate the pinecone vector database, run the followings
#
# python katslib/opkatsDataUtil.py
#
# run this notebook (kats_pattern_vectordb.ipynb) to see the pattern matching outcome

# %%
from katslib.opkatsDataUtil import init_kat_index
ki=init_kat_index()
ki.describe_index_stats()

# %%
from opkatsPatternMatcherUtil import opkatsPatternMatcherUtil
fname=opkatsPatternMatcherUtil.match_period_with_vectordb('NVDA')
fname
# Out:
# /home/jackylee/anaconda3/lib/python3.9/site-packages/linear_operator/utils/deprecation.py:13: UserWarning: Failed to initialize NumPy: module compiled against API version 0xf but this version of numpy is 0xe (Triggered internally at /root/pytorch/torch/csrc/utils/tensor_numpy.cpp:77.)
#   bool_compat = (torch.ones(1) > 0).dtype
# WARNING:root:kats.utils.time_series_parameter_tuning requires ax-platform be installed
# WARNING:root:kats.models.metalearner.get_metadata requires ax-platform be installed
# /home/jackylee/git_tutorial/timeseriesVectorDBPatterMatcher/opkatsPatternMatcherUtil.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['_date']=new_df.index
# /home/jackylee/git_tutorial/timeseriesVectorDBPatterMatcher/katslib/opkatsDataUtil.py:180: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['_date']=df.index
# /home/jackylee/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/stattools.py:1906: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   warnings.warn(
# query_results len is  20
# ticker: NVDA
# ticker: UFAB
# ticker: KSS
# ticker: VNET
# ticker: INMB
# ticker: EGO
# ticker: SI
# ticker: NATR
# ticker: ALEC
# ticker: COMM

# %%
import matplotlib.pyplot as plt

# Create a sample plot with legends
x = [1, 2, 3, 4]
y1 = [10, 15, 13, 17]
y2 = [16, 5, 11, 9]

plt.plot(x, y1, label='Line 1')
plt.plot(x, y2, label='Line 2')
plt.legend(loc='upper center')

# Move the legends to the bottom and arrange them horizontally
plt.legend(loc='lower center', ncol=2, bbox_to_anchor=(0.25, -0.25))

plt.show()

# %%
import pandas as pd

# Create a sample dataframe
df = pd.DataFrame({'A': [1, 2, 3], 'B': ['a', 'b', 'c']})

# Create a new row to append
new_row = {'A': 4, 'B': 'd'}

# Append the new row to the dataframe
df = df.append(new_row, ignore_index=True)

# View the updated dataframe
print(df)
# Out:
#    A  B
# 0  1  a
# 1  2  b
# 2  3  c
# 3  4  d
